# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = pd.read_csv("haberman.csv")
data[0:10]
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1
# 5  33  60   0    1
# 6  34  59   0    2
# 7  34  66   9    2
# 8  34  58  30    1
# 9  34  60   1    1

# %%
X = np.array(data)
np.sort(X)
col1 = X[:,0]; # seria 1
col2 = X[:,1]; # seria 2
col3 = X[:,2]; # seria 3
col4 = X[:,3]; # seria 4

# %%
data = pd.read_csv('haberman.csv')


# Utwórz 3D scatter plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Ustaw kolor punktów na podstawie wartości w kolumnie 'Status'
colors = np.where(col4 == 1, 'green', 'red')

# Wygeneruj scatter plot
ax.scatter(col1, col2, col3, c=colors, marker='o', s=50, edgecolors='k', alpha=0.7)

# Ustaw etykiety dla każdej osi
ax.set_xlabel('Col1 Label')
ax.set_ylabel('Col2 Label')
ax.set_zlabel('Col3 Label')

# Ustaw tytuł wykresu
ax.set_title('3D Scatter Plot of Haberman Data with Status')

plt.show()

# %%
feature_indices = [10, 63, 175, 216, 252]

mean_1 = np.mean(X[:,0])
mean_2 = np.mean(X[:,1])
mean_3 = np.mean(X[:,2])

std_dev_1 = np.std(X[:,0])
std_dev_2 = np.std(X[:,1])
std_dev_3 = np.std(X[:,2])

lower_bound_1 = mean_1 - 3 * std_dev_1
upper_bound_1 = mean_1 + 3 * std_dev_1
lower_bound_2 = mean_2 - 3 * std_dev_2
upper_bound_2 = mean_2 + 3 * std_dev_2
lower_bound_3 = mean_3 - 3 * std_dev_3
upper_bound_3 = mean_3 + 3 * std_dev_3

# %%
outliers_indices_1 = []
outliers_indices_2 = []
outliers_indices_3 = []
# for i in range(len(X)):
outliers_1 = np.where((X[:,0] < lower_bound_1) | (X[:,0] > upper_bound_1))[0]
outliers_2 = np.where((X[:,1] < lower_bound_2) | (X[:,1] > upper_bound_2))[0]
outliers_3 = np.where((X[:,2] < lower_bound_3) | (X[:,2] > upper_bound_3))[0]

print(outliers_3)
# Out:
# [  8  61 173 214 251]
