# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
data = pd.read_csv("haberman.csv")
data[0:10]
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1
# 5  33  60   0    1
# 6  34  59   0    2
# 7  34  66   9    2
# 8  34  58  30    1
# 9  34  60   1    1

# %%
X = np.array(data)
col1 = X[:,0]; # seria 1
col2 = X[:,1]; # seria 2
col3 = X[:,2]; # seria 3
col4 = X[:,3]; # seria 4

# %%
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.scatter(col1,col2,col3, marker='s')
# plt.show()
x_min = np.min(col1)
x_max = np.max(col1)
y_min = np.min(col2)
y_max = np.max(col2)
z_min = np.min(col3)
z_max = np.max(col3)
X = np.arange(x_min, x_max+1)
Y = np.arange(y_min, y_max+1)
Z = np.arange(z_min, z_max+1)

# for i in range(np.size(X)):
#     ax.scatter(X, col1, marker='r')
# for i in range(np.size(Y)):
#     ax.scatter(Y, col2, marker='g')
# for i in range(np.size(Z)):
#     ax.scatter(Z, col3, marker='b')
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(col1, col2, col3);

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with different colors based on the values in label_column
scatter = ax.scatter(col1, col2, col3, c=label_column, cmap='viridis', marker='o', s=50, edgecolors='k', alpha=0.7)

# Add a colorbar to show the mapping of colors to values in label_column
colorbar = plt.colorbar(scatter)
colorbar.set_label('Label Column')

# Set labels for each axis
ax.set_xlabel('Col1 Label')
ax.set_ylabel('Col2 Label')
ax.set_zlabel('Col3 Label')

# Set a title for the plot
ax.set_title('3D Scatter Plot of Haberman Data')

plt.show()
